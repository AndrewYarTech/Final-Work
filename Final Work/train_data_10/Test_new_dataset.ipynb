# %%
import numpy
# scipy.special для вызова сигмоиды
import scipy.special
# для работы с векторами
import matplotlib.pyplot
# чтобы запуск происходил в блокноте
# %matplotlib inline

# %%
# helper to load data from PNG image files
import imageio
# glob helps select multiple files using patterns
import glob

# %%
for image_file_name in glob.glob('??.jpg'):
    print ("Загрузка... ", image_file_name)
    # use the filename to set the correct label
    if image_file_name == '01.jpg':
        label = 1
    else:
        label = 0
    # load image data from png files into an array
    img_array = imageio.imread(image_file_name, as_gray=True)
    # reshape from 28x28 to list of 784 values, invert values
    img_data  = 255.0 - img_array.reshape(784)
    # then scale data to range from 0.01 to 1.0
    img_data = (img_data / 255.0 * 0.99) + 0.01
    print(numpy.min(img_data))
    print(numpy.max(img_data))
    # append label and image data  to test data set
    record = numpy.append(label,img_data)
    print(record)
    our_own_dataset.append(record)
    pass
print(our_own_dataset)
# Out:
# Загрузка...  01.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-af315c72e1f5> in <module>
#       9     img_array = imageio.imread(image_file_name, as_gray=True)
#      10     # reshape from 28x28 to list of 784 values, invert values
# ---> 11     img_data  = 255.0 - img_array.reshape(784)
#      12     # then scale data to range from 0.01 to 1.0
#      13     img_data = (img_data / 255.0 * 0.99) + 0.01
#
# ValueError: cannot reshape array of size 1366561 into shape (784,)
